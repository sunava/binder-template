# %% [markdown]
# Copyright © 2024 Vanessa Hassouna.
#
# This Work is licensed under the [BSD 3-Clause](https://opensource.org/licenses/BSD-3-Clause) License.
#
# If you have questions or the demo is not working, write to the author at hassouna@uni-bremen.de.
#
# # Live Demo
# ### <span style="color:red">Please wait till you see the robot on the right side to click play!</span>

# %%
from demo_launcher import show_demo_launcher

show_demo_launcher()
# Out:
# VBox(children=(HTML(value='\n        <h2 style="margin: 0 0 8px;">Demo Setup</h2>\n        <p style="margin: 0…
